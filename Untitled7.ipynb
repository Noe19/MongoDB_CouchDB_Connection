# %%
import json
from argparse import ArgumentParser
import requests
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
from bson import json_util, ObjectId
import couchdb

URL = 'http://admin:admin@127.0.0.1:5984'
print(URL)

try:
    response = requests.get(URL)
    if response.status_code == 200:
        print('CouchDB connection: Success')
    if response.status_code == 401:
        print('CouchDB connection: failed', response.json())
except requests.ConnectionError as e:
    raise e

server=couchdb.Server(URL)
HEADERS = {
    'Accept': 'application/json',
    'Content-Type': 'application/json'
}


CLIENT = MongoClient("mongodb+srv://admin:admin123456@cluster0.vvf1t.mongodb.net/deber?retryWrites=true&w=majority")
db = CLIENT.deber

try:
    CLIENT.admin.command('ismaster')
    print('MongoDB connection: Success')
except ConnectionFailure as cf:
    print('MongoDB connection: failed', cf)


DBS=['deber']


try:
    dbc=server.create('mongo_destino2')
except:
    dbc=server['mongo_destino2']
    

for db in DBS:
    if db not in ('admin', 'local','config'):  
        cols = CLIENT[db].list_collection_names()  
        for col in cols:
            print('Querying documents from collection {} in database {}'.format(col, db))
            for x in CLIENT[db][col].find():  
                try:
                    
                    documents=json.loads(json_util.dumps(x))

                    documents["_id"]=str(documents["_id"]["$oid"])


                    print(documents)
                    doc=dbc.save(documents)

                except TypeError as t:

                    print('current document raised error: {}'.format(t))
                    SKIPPED.append(x)  # creating list of skipped documents for later analysis
                    continue    # continue to next document
                except Exception as e:
                    raise e
# Out:
# http://admin:admin@127.0.0.1:5984
# CouchDB connection: Success
# MongoDB connection: Success
# Querying documents from collection Iván Fraga in database deber
# {'_id': '60f8dbbf4ad77e85c0696f4d', 'title': 'devhelp build is broken', 'body': '\\r   file \\ pgi-docgen/_docs/glib-2.0/_ext/devhelp_fork.py\\ , line 128, in build_devhelp\\r     for title,  refs, subitems  in group:\\r valueerror: too many values to unpack\\r    \\r \\r i guess some sphinx changes..'}
# {'_id': '60f8dbbf4ad77e85c0696f61', 'title': 'keybase encryption in provider is causing a panic', 'body': "terraform version\\r    \\r 2018/03/08 09:47:52  info  terraform version: 0.11.3  3802b14260603f90c7a1faf55994dcc8933e2069\\r 2018/03/08 09:47:52  info  go runtime version: go1.9.1\\r    \\r \\r     terraform configuration files\\r \\r regular pgp keys work:\\r \\r    hcl\\r resource \\ mysql_user_password\\  \\ jstump\\  {\\r   user = \\ ${mysql_user.jstump.user}\\ \\r   pgp_key = <<eod\\r ...base64 encoded pgp key...\\r eod\\r }\\r    \\r \\r  keybase:username  causes a panic:\\r \\r    \\r resource \\ mysql_user_password\\  \\ jstump\\  {\\r   user = \\ ${mysql_user.jstump.user}\\ \\r   pgp_key = \\ keybase:plathrop\\ \\r }\\r    \\r \\r     crash output\\r \\r https://gist.github.com/joestump/fa93e40d35dfdf8e4a6e26685719b2fa\\r \\r     expected behavior\\r \\r it should pull the keybase pgp key and encrypt. i've been going off of the code in   aws_iam_access_key   https://github.com/terraform-providers/terraform-provider-aws/blob/master/aws/resource_aws_iam_access_key.go l81-l98  to create a   mysql_user_password   https://github.com/terraform-providers/terraform-provider-mysql/pull/30  resource.\\r \\r     actual behavior\\r \\r it panics when i attempt to pull from keybase. it works fine when a base64 encoded pgp key is passed instead.\\r \\r     steps to reproduce\\r \\r   check out that pr.\\r   try using keybase  keybase:username  and you'll get a panic.\\r   use a regular base64 encoded pgp key and it'll work.\\r \\r     references\\r \\r related to pr https://github.com/terraform-providers/terraform-provider-mysql/pull/30"}
# {'_id': '60f8dbbf4ad77e85c0696f47', 'title': 'unable to mine rocks', 'body': "sarkasmo starting today, when i hit enter  action  on a rock, my avatar freezes for about 15 seconds and then unfreezes, but the action menu never shows up and i don't get to mine any rocks.       user agent     mozilla/5.0  windows nt 10.0; wow64  applewebkit/537.36  khtml, like gecko  chrome/48.0.2564.116 safari/537.36         log      server communication  map data loaded. 0:00:02\\r  authmanager  setting api tokens 0:00:03\\r  authmanager  logged in 0:00:03\\r  streetservice  requesting street \\ ga9klb7i1d822ol\\ ... 0:00:03\\r  soundmanager  registered services 0:00:03\\r  streetservice  \\ ga9klb7i1d822ol\\  loaded. 0:00:03\\r  streetservice  assembling street... 0:00:03\\r  streetservice  street assembled. 0:00:10\\r  ui  sorry, this browser does not support the gamepad api 0:00:11\\r game loaded! 0:00:11\\r  mapwindow  could not check visited status of street bettano testament: nullerror: method not found: 'bi' on null 0:00:32\\r  mapwindow  could not check visited status of street mimosa mix: nullerror: method not found: 'bi' on null 0:00:32\\r  mapwindow  could not check visited status of street chima chore: nullerror: method not found: 'bi' on null 0:00:32\\r  mapwindow  could not check visited status of street matsua mossy: nullerror: method not found: 'bi' on null 0:00:32\\r  mapwindow  could not check visited status of street shoga links: nullerror: method not found: 'bi' on null 0:00:32\\r  streetservice  requesting street \\ gnvea19502i2s8m\\ ... 0:01:25\\r  streetservice  \\ gnvea19502i2s8m\\  loaded. 0:01:26\\r  streetservice  assembling street... 0:01:26\\r  streetservice  street assembled. 0:01:31\\r  mapwindow  could not check visited status of street bettano testament: nullerror: method not found: 'bi' on null 0:01:31\\r  mapwindow  could not check visited status of street mimosa mix: nullerror: method not found: 'bi' on null 0:01:31\\r  mapwindow  could not check visited status of street chima chore: nullerror: method not found: 'bi' on null 0:01:31\\r  mapwindow  could not check visited status of street matsua mossy: nullerror: method not found: 'bi' on null 0:01:31\\r  mapwindow  could not check visited status of street shoga links: nullerror: method not found: 'bi' on null 0:01:31\\r  mapwindow  could not check visited status of street cryptocrin: nullerror: method not found: 'bi' on null 0:04:07\\r  server communication  sending commune with to entity: n426628037  npc  with arguments: null 0:05:19\\r  server communication  sending donate to entity: n426628037  npc  with arguments: {itemtype: chunk_beryl, qty: 99} 0:05:55\\r  server communication  sending donate to entity: n426628037  npc  with arguments: {itemtype: chunk_beryl, qty: 99} 0:06:29\\r  server communication  sending close to entity: n426628037  npc  with arguments: {} 0:06:37\\r"}
# {'_id': '60f8dbbf4ad77e85c0696f65', 'title': 'redistricting not applied to meshblocks', 'body': '\\ redistrict some meshblocks, then click on the electorate statistics button, and click in the area just redistricted. electorate statistics for the electorate they were previously assigned to still appear.\\'}
# {'_id': '60f8dbbf4ad77e85c0696f94', 'title': 'hard code wifi or wait longer to connect', 'body': "is there a way to hardcode the wifi settings?\\r i have installed the led's in a mobile setup.\\r the box contains a wifi access point and a wmos d1 mini with mclighting on it. but the access points need some more time to boot. but the wmos will connect to the wifi but will present me the config site when i surf the ip address."}
# {'_id': '60f8dbbf4ad77e85c0696fa1', 'title': 'refactor the structure', 'body': 'the following features must be added\\r - separate list/dictionary creation, crawler and import/update database logics\\r - run each crawler independently on the terminal by giving a specific year and month'}
# {'_id': '60f8dbbf4ad77e85c0696fa5', 'title': 'horrible formatting on arts & crafts page', 'body': 'fix insane sizes of both iframe and pic'}
# {'_id': '60f8dbbf4ad77e85c0696fad', 'title': 'add additional cli yaml attributes to reference section', 'body': 'currently the yaml section at https://docs.openfaas.com/reference/yaml/ is fairly complete, however it misses some of the more recent features:\\r \\r - build_options\\r - readonly_root_filesystem\\r - skip_build'}
# {'_id': '60f8dbbf4ad77e85c0696fae', 'title': 'mac libdb2.dylib image not found', 'body': '\\r >>> import ibm_db\\r traceback  most recent call last :\\r   file \\ <stdin>\\ , line 1, in <module>\\r importerror: dlopen /usr/local/lib/python3.5/site-packages/ibm_db.cpython-35m-darwin.so, 2 : library not loaded: libdb2.dylib\\r   referenced from: /usr/local/lib/python3.5/site-packages/ibm_db.cpython-35m-darwin.so\\r   reason: image not found\\r    \\r \\r this issue can be solved by running\\r    bash\\r cd /usr/local/lib/python3.5/site-packages\\r install_name_tool -change libdb2.dylib  pwd /libdb2.dylib ibm_db.cpython-35m-darwin.so\\r    \\r http://thecourtsofchaos.com/2013/09/16/how-to-copy-and-relink-binaries-on-osx/\\r \\r however, this needs to be run after pip compiles it. \\r http://stackoverflow.com/questions/1321270/how-to-extend-distutils-with-a-simple-post-install-script'}
# {'_id': '60f8dbbf4ad77e85c0696fb1', 'title': 'improve usage documentation', 'body': 'improve the usage example in the readme.md.\\r \\r instead of listing various random functions, better give one more complete example.'}
# {'_id': '60f8dbbf4ad77e85c0696fc8', 'title': "disabling \\ fixed-dock\\  doesn't hide dock in fullscreen instantly", 'body': "hi,  i've configured a shortcut to hide the dock when i press it.  however the dock is still shown when pressing this shortcut and have apps on my monitor in full screen. i have to change focus before it'll minimize.  would you be able to make it hide instantly?  whatever \\ intelligent hide\\  is enabled or not makes no difference.  the command my script is executing is this one: <b>dconf write /org/gnome/shell/extensions/dash-to-dock/dock-fixed false</b>"}
# {'_id': '60f8dbbf4ad77e85c0696fed', 'title': 'html parser incorrectly handles multiple items per person', 'body': 'input\\r \\r | html | screencap |\\r | --- | --- |\\r |  html.zip  https://github.com/mergemypullrequest/order-splitter/files/1142722/html.zip  | ! screen shot 2017-07-12 at 12 41 04 pm  https://user-images.githubusercontent.com/2660313/28128938-65eeef44-66ff-11e7-81d1-04de63f4fb67.png  |\\r \\r    result\\r \\r https://jonsmithers.github.io/order-splitter/?tax=2.91&fee=4.78&tip=8.91&larry=11.60&benjamin=11.49&smithers=8.50&daniel=9.99\\r'}
# {'_id': '60f8dbbf4ad77e85c069700d', 'title': 'refactor document button', 'body': "despite just committing it, the new behavior of the document vs. word search button is not ideal for long-term maintenance.  currently there are a ton of checks for the  $ ' autocmopletedoc'   and code to toggle the click status based on  $ ' hiddenid' .val   . these could all simply be handled by an event handler on  $ ' hiddenid'  , but  input type='hidden'   fields do not fire  change  events. therefore a  mutationobserver  https://developer.mozilla.org/en-us/docs/web/api/mutationobserver  should be used to monitor changes to the dom on the hiddenid and cascade to the input. in this mock up stage, i did not learn the api though, so a future refactor will be necessary.  one primary reason for not implementing now is browser compatability. mutationobservers require ie11, and that is not widely distributed yet.  whichbrowser  https://github.com/whichbrowser/whichbrowser  provides a way to do feature checking, but i don't yet want to do browser requirement notifications on the topic explorer."}
# {'_id': '60f8dbbf4ad77e85c0697014', 'title': 'can opennmt-tf be used for a neural spell checker?', 'body': 'hello opennmt-tf team,\\r \\r can opennmt-tf be used to train a neural spell-checker model? \\r \\r thanks'}
# {'_id': '60f8dbbf4ad77e85c069701a', 'title': 'how i can set image to point chart?', 'body': "chart type 'bubble'\\r i want to set image to point like that\\r  ! picture-matrix.png  http://sv1.upsieutoc.com/2017/10/25/picture-matrix.png   http://www.upsieutoc.com/image/plqtxk \\r thanks"}
# {'_id': '60f8dbbf4ad77e85c0697028', 'title': 'limited emails list.', 'body': 'the user is allowed to see only 25 emails per category, gmail activity must allow see older emails.'}
# {'_id': '60f8dbbf4ad77e85c0697040', 'title': 'putting all components together and running test period', 'body': 'we need\\r - a deployment plan  which component runs where \\r - set all components off and interact with the same database\\r - start monitoring what comes in and debug immediately\\r \\r i propose we get all code done by friday this week to have time to start testing our middleware roundtrip from observation, via project and task creation, to task publication and collection of task performances.'}
# {'_id': '60f8dbbf4ad77e85c0697046', 'title': 'add ui indicator linked to pump blockage', 'body': 'when the sample pump block signal on the crd_hk card goes high it indicates that the system has been pumped down below ~200mbar causing the sample pump to be automatically shut off.\\r \\r need to add indicator to the ui to indicate this has happened. logging of this signal is not required.'}
# {'_id': '60f8dbbf4ad77e85c069704b', 'title': 'external wiki link opens in new window/tab, external issue link does not', 'body': "it's an inconsistency: the \\ wiki\\  tab link, when using external wiki, opens in a new tab/window, while the \\ issues\\  tab link, when using external issues, opens int the same tab/window.\\r \\r \\\\cc @geek1011  just because i remember you contributed ui stuff, so betting on you :"}
# {'_id': '60f8dbbf4ad77e85c069704f', 'title': 'any wiki page to explain the metrics?', 'body': 'in fact, i am confused by the metrics got from the monitoring page, e.g.  % system cpu .\\r \\r but i got  % system cpu is the cpu usage for the whole system  not just the jvm , between 0 and 100%.  from the release notes. surprised.'}
# {'_id': '60f8dbbf4ad77e85c0697056', 'title': 'existence of definitions in \\ variables\\  section not checked', 'body': "- packer v0.10.2 - osx 10.11.6  the  documentation for user variables  https://www.packer.io/docs/templates/user-variables.html  says:  > user variables must first be defined in a variables section within your template.  however this is not enforced: i accidentally missed a variable out of the \\ variables\\  section and there was no complaint.  simple reproducing case:      {   \\ variables\\ : {   },    \\ builders\\ :       {       \\ type\\ :         \\ null\\ ,       \\ ssh_host\\ :     \\ 127.0.0.1\\ ,       \\ ssh_username\\ : \\ xxx{{ user  foo  }}\\ ,       \\ ssh_password\\ : \\ xxx{{ user  bar  }}\\      }     }      this is happily accepted by  packer build  and  packer validate , even if you don't specify any  -var foo=...  or  -var bar=...  flags on the command line.  the flip side of this gives a second, related issue: you are allowed to define variables on the command line which are _not_ listed in the variables section. for example:      packer build -var xyzzy=12345 foo.json      is happily accepted, even if there is no \\ xyzzy\\  defined in \\ variables\\   i believe the intention was that both the above cases should raise errors; but if not, the documentation needs clarifying."}
# {'_id': '60f8dbbf4ad77e85c069705e', 'title': 'packager cannot parse h264 nalu created by x264 library when it is of fixed size', 'body': 'the packager cannot read an input stream or file if you make such a stream or file with any x264 option that will create a fixed size nalu. x264 options include slice-max-size=x, slices=x, tune=zerolatency, etc\\r the packager errors out with:\\r  0811/090118:error:packager_main.cc 503   packaging error: 8  parser_failure : cannot parse media file'}
# {'_id': '60f8dbbf4ad77e85c0697061', 'title': "the core api section should explain it's not meant to be used by end users", 'body': "we expect most of users to use the pipeline api. however the \\ the core api\\  section in the manual is quite extensive and it creates an impression it's something i need to learn before using jet. \\r \\r there should be a clear warning it's meant to be directly used by advanced users only."}
# {'_id': '60f8dbbf4ad77e85c0697068', 'title': 'pre 1.6 instant heal suggestion', 'body': "can you please add an option to enable 1.6 instant healing when using foods?\\r also an option to set healing amount for each food.  1-20, 0 = no heal you can eat, negative values = damage you \\r e.g.\\r chicken: 5  this'll add 5 health to your 20 healths instantly \\r rotten_flesh: -3  this'll damage you by 3 healths.  if player can't handle it and might die then cancel the event till 1 healths!  \\r golden_apple: 0  if you hold right-click on this apple you must eat it but it wont add any healths to you it'll just do the same effects. it'll add 4 hungerbars to your hunger if the option below is disabled. \\r \\r a great example for this feature is fastfood. you can also search this plugin in spigot yourself.  that plugin is outdated. it was for 1.8 \\r \\r also an option next to it to disable hungerbar next to it  always full hungerbar \\r also an option next to it to disable regeneration when your hungerbar is full  however the is a gamerule in /gamerule to disabled that \\r \\r i know this plugin is made to be for 1.8 pvp but this would be awesome!\\r thanks!"}
# {'_id': '60f8dbbf4ad77e85c0697070', 'title': 'avoid hourly anti-sampling when its just a one day fetch', 'body': 'it could just be there is one day left, not the session limiting it to one day'}
# {'_id': '60f8dbbf4ad77e85c0697073', 'title': 'knowledge skill category overwritten on load', 'body': "environment\\r chummer version: 5.193.45\\r environment: windows 7\\r runtime:  if you don't know this, it is probably .net 4.5.1 \\r \\r     expected behaviour\\r the knowledge skill category should only be set automatically if no category is set.\\r that would preserve manuall changes of the category.\\r \\r     actual behaviour\\r adding a new knowledge skill by selecting one from the combobox automatically sets the category  hobby, street, academic, ... . if i choose another category that looks fine so far.\\r after saving, closing and reopening the character, the knowledge skill category is reseted to the automatically choosen category. the manual set category is lost.\\r \\r     steps to reproduce the behaviour\\r create a new character.\\r add a knowledge skill from the combobox.\\r change the knowledge skill category.\\r save, close and reopen the character.\\r"}
# {'_id': '60f8dbbf4ad77e85c06970ac', 'title': 'crossing history on user view - its slow to load', 'body': "noted by watershed. but i think that this only happens to non-logged-in users. i think the history query's permissions are not set for floods_anonymous"}
# {'_id': '60f8dbbf4ad77e85c06970b6', 'title': 'broken link in documentation', 'body': 'today,  a link was found to be broken  https://epics.anl.gov/tech-talk/2018/msg00960.php  in the nexus documentation.\\r \\r \\ see: http://download.nexusformat.org/doc/html/design.html?highlight=master combining-nexus-links-and-external-file-links\\r \\r \\ that page has a broken link to be fixed shortly.  this is the correct link: http://download.nexusformat.org/doc/html/examples/h5py/index.html links-to-data-in-external-hdf5-files\\r \\'}
# {'_id': '60f8dbbf4ad77e85c06970d6', 'title': 'add weapon stats system', 'body': 'add weapon stats system:\\r \\r   atk calculation\\r   ...'}
# {'_id': '60f8dbbf4ad77e85c06970de', 'title': 'multiple email notification when purchase is made from multiple vendors', 'body': 'when a customer purchased from more that one vendor he receives multiple emails. for four vendors the customer gets four emails because of the dub orders. a customer should get one email and the suborder should be mentioned in the emails with the order details and store details'}
# {'_id': '60f8dbbf4ad77e85c06970e3', 'title': 'improve shown error when stampede is trying to replicate from a mongodb whose version is not 3.2', 'body': "the issue  130 reported by @p1nox indicates that when stampede is trying to replicate from a mongodb 3.4, the error shown is  syntethized  the following:\\r    \\r 2016-12-22t04:01:30.851 error 'recoveryservice' c.t.m.r.replcoordinator fatal error while starting recovery mode: not supported yet\\r 2016-12-22t04:01:30.854 error 'recoveryservice' c.t.m.r.mongodbreplbundle catched an error on the replication layer. escalating it\\r 2016-12-22t04:01:30.855 error 'recoveryservice' c.t.s.stampedeservice error reported by replication supervisor. stopping torodb stampede\\r    \\r \\r it should say something like \\ it is not supported to replicate from mongodb version _whatever_\\"}
# {'_id': '60f8dbbf4ad77e85c06970e6', 'title': 'next update circle around player', 'body': "i think it's important, like showing the nearby pokemons in the map in the circle.\\r"}
# {'_id': '60f8dbbf4ad77e85c06970ea', 'title': "mentions don't change after a user changed his name", 'body': "- write a mention post for user a - change user a's display name - the mention still has the old name    <bountysource-plugin>  want to back this issue?    post a bounty on it!  https://www.bountysource.com/issues/285-mentions-don-t-change-after-a-user-changed-his-name?utm_campaign=plugin&utm_content=tracker%2f522&utm_medium=issues&utm_source=github    we accept bounties via  bountysource  https://www.bountysource.com/?utm_campaign=plugin&utm_content=tracker%2f522&utm_medium=issues&utm_source=github . </bountysource-plugin>"}
# {'_id': '60f8dbbf4ad77e85c0696f6a', 'title': 'suggestion: load json from url', 'body': 'i use this collaboratively with some other people in my town, and it would be nice to be able to keep everyone on the same version of our local data. it would be useful to have a setting where we could all just plug in a url to a file in my github as a setting, push our changes to that and have them automatically show up for everyone else.'}
# {'_id': '60f8dbbf4ad77e85c0696f76', 'title': "rainbow doesn't warn me when critical path length settings are different than expected", 'body': "do you want to request a  feature  or report a  bug ?  \\r a quality of life improvement\\r \\r   what is the current behavior?  \\r today, it is possible for users  developers, usually  to change the rainbow.config settings for serializationfolderpathmaxlength and maxitemnamelengthbeforetruncation  presumably to accommodate for a long local root path  and forgetting that this setting needs to be _the same_ across _all_ environments and as such should never be touched locally.\\r \\r   if the current behavior is a bug, please provide the steps to reproduce.  \\r just change either of these settings without reserializing the repository. all sorts of item missing errors will occur, or cases of items not being serialized as expected. these issues are almost invisible and very hard to debug.\\r \\r   what is the expected behavior?  \\r that rainbow tries it's durn best to detect this and prevent this situation from going unchecked.\\r \\r   please mention your sitecore version, rainbow version, and if also using unicorn, your version of that too.  \\r any\\r"}
# {'_id': '60f8dbbf4ad77e85c0696f46', 'title': 'crash indien vol', 'body': 'de simulator crasht als hij vol zit'}
# {'_id': '60f8dbbf4ad77e85c0696f4c', 'title': 'tests: test suite for distributed setup.', 'body': "currently the test suites for xl and fs backend exists. its necessary to have test suite for minio distributed so that any undesirable changes doesn't break the distributed functionality."}
# {'_id': '60f8dbbf4ad77e85c0696f4a', 'title': 'multi-day bookings are no longer visually represented on the calendar', 'body': '<img width=\\ 691\\  alt=\\ bildschirmfoto 2017-05-24 um 18 23 43\\  src=\\ https://cloud.githubusercontent.com/assets/4009931/26414048/359b0a5c-40ae-11e7-938c-9cce77852dcf.png\\ >\\r \\r mutli-day bookings are visible, but not \\ connected\\'}
# {'_id': '60f8dbbf4ad77e85c0696f55', 'title': 'ibm unity sdk demo scene testspeechtotext not working', 'body': '> question by muhammad faizan khan   1  | sep 09 at 02:58 am\\r > i have downloaded unity sdk of ibm watson but the problem  necessary after configuration , its testspeechtotext scene still not working. no log, no output while i am continuously giving voice input. what else settings are required to run the scene. i also inspect its different script that is attached to game objects some of them have not assigned ui game-object.\\r \\r source: https://developer.ibm.com/answers/questions/399772/demo-scene-testspeechtotext-not-working.html'}
# {'_id': '60f8dbbf4ad77e85c0696f67', 'title': 'debugger  number of variables are wrong when variables with same name are declared in each block of try statement', 'body': 'issue:  \\r \\r when there are multiple variables declared inside a try-catch-finally block with the same name on debug it list down five variables in that name when there is only 3 variables declared. this is only happening for try-catch block. \\r \\r   sample code  \\r    js\\r import ballerina.lang.errors;\\r \\r function main  string   args  {\\r     string   data = null;\\r     int   i1 =  1, 2, 3 ;\\r     try {\\r         int i = 34;\\r     } catch  errors:nullreferenceerror nul {\\r         int i = 34;\\r     }\\r     catch  errors:error err {\\r             int i = 45;\\r     }\\r     finally{\\r             int i = 56;\\r     }\\r }\\r    \\r \\r when debug variable listing shows 5 variables with the name   \\ i\\'}
# {'_id': '60f8dbbf4ad77e85c0696f6d', 'title': 'parabolic sar is incorrect', 'body': 'please check parabolic sar calculations. indicator results looks incorrect. comparation with mt4 sar fails with a bang.'}
# {'_id': '60f8dbbf4ad77e85c0696f6f', 'title': 'canonical paths: check equivalence', 'body': 'for the moment we allow users to annotate module definitions with      @canonical some.path     but we do not check that  some.path  is indeed equivalent to the module being defined.'}
# {'_id': '60f8dbbf4ad77e85c0696fb8', 'title': 'need better mapping from property to search parameter for data providers', 'body': 'take for example the date path observation.effective. the search parameter would be \\ date\\ , but the providers are attempting to use \\ effective\\ . suggesting that mappings are added to providers for all resources for all versions.'}
# {'_id': '60f8dbbf4ad77e85c0696fcb', 'title': 'create a database structure for system administrators', 'body': 'create a database schema for the system administrators.'}
# {'_id': '60f8dbbf4ad77e85c0696fe4', 'title': "\\ away\\  status doesn't revert automatically", 'body': 'brief description\\r \\r os: arch linux\\r qtox version: v1.6.0-113-g9c325638\\r commit hash: 9c3256386d0b28b5f9a24b2a3979f7326722970a\\r toxcore: 0.1.0\\r qt: 5.7.1\\r \\r reproducible: sometimes\\r \\r       steps to reproduce\\r \\r 1. setup small auto-away time\\r 2. setup \\ online\\  status\\r 3. wait unitl your status will be \\ away\\ \\r 4. disable network without any ui activity  take out the wire or use ssh to stop demon \\r 5. enable network\\r 6. wait some time to make tox reconnect\\r 7. do an activity\\r \\r       observed behavior\\r status still \\ away\\ \\r \\r       expected behavior\\r revert status'}
# {'_id': '60f8dbbf4ad77e85c0696fe8', 'title': 'play button in visualization area', 'body': 'add a play button in the visualisation area with an overlay. \\r \\r ! image  https://cloud.githubusercontent.com/assets/749854/13732245/59676224-e97e-11e5-8ddb-36f5af45c53c.png \\r \\r'}
# {'_id': '60f8dbbf4ad77e85c069701f', 'title': 'reported viewcontroller is always nil', 'body': "when you call viewcontrollerobserverreporter -reportpossibleviewcontrollerleak:, the viewcontroller parameter is always nil. this is because you're passing viewcontroller into it, which was set to nil right before you enter the dispatch_after   block. you probably meant to pass in weakviewcontroller instead.\\r \\r or better yet, do something like this instead of testing weakviewcontroller directly:\\r \\r     uiviewcontroller  strongviewcontroller = weakviewcontroller;\\r     if  strongviewcontroller  { \\r                 self.reporter reportpossibleviewcontrollerleak:strongviewcontroller ;\\r     }\\r \\r this would work around a very unlikely, but possible, race condition where weakviewcontroller exists when you test it in the 'if' statement, but gets dealloced from some other thread before you get a chance to do anything with it."}
# {'_id': '60f8dbbf4ad77e85c0697037', 'title': 'new files are not indexed', 'body': 'when moving files or creating new files, they are not indexed correctly, and cannot be searched for or jumped to with alt+g.'}
# {'_id': '60f8dbbf4ad77e85c069704e', 'title': "tw-820  patch - man page update for 'entry' attribute", 'body': "_duane waddle on 2011-04-19t22:37:15z says:_    patch to update man page to provide docs on 'entry' attribute.  <pre> diff --git a/doc/man/task.1.in b/doc/man/task.1.in index bf672d9..302790c 100644 --- a/doc/man/task.1.in +++ b/doc/man/task.1.in @@ -435,6 +435,12 @@ declares this task to be dependent on id1 and id2.  this means that the tasks  id1 and id2 should be completed before this task.  consequently, this task will  then show up on the 'blocked' report.   +.tp +.b entry:<entry-date> +for report purposes, specifies the date that a task was created.  the entry +attribute cannot be directly specified using task add, and should not be edited +after creating the task. +  .sh attribute modifiers  attribute modifiers improve filters.  prefixing any modifier with '~' returns  the complementary set of items.  supported modifiers are: </pre>"}
# {'_id': '60f8dbbf4ad77e85c0697076', 'title': 'add search for text in standards codes', 'body': "this would align search more closely to searching by student outcomes, e.g. 'able to form hypothesis' or 'able to refine hypothesis'"}
# {'_id': '60f8dbbf4ad77e85c069707c', 'title': 'phases do not inherit colour correctly', 'body': "when colour is inherited from the 'based on' phase, it is not changed accordingly."}
# {'_id': '60f8dbbf4ad77e85c069708c', 'title': 'code editor goes outside its bounds', 'body': "godot version:  \\r master: d81bd96\\r \\r \\r   issue description:  \\r i first made an  issue  https://github.com/godotengine/godot/issues/12012  thinking that the problem was with the search/replace bar, but it happens even with without them. the vsplitcontainer should stop dragging once it has reached the limit, but it just keeps going until it's outside the bounds of it.\\r \\r ! bug  https://user-images.githubusercontent.com/30739239/34129620-eb3a91f4-e42b-11e7-8c5c-30fe873a87fb.gif"}
# {'_id': '60f8dbbf4ad77e85c0697098', 'title': 'add a posibility to clear output and problems text boxes', 'body': 'the output  stdout  and problems  stderr  text boxes may get overwhelmed with outdated information. it would be nice to have an option to clear these text boxes  e.g. via a popup menu .    ------------------------------------ this issue was imported from a launchpad blueprint.     name: ui-std-clear    date created: 2014-02-05t16:36:05z    date closed: 2014-08-01t17:05:55z    assignee: danilovesky    the launchpad url was https://blueprints.launchpad.net/workcraft/+spec/ui-std-clear'}
# {'_id': '60f8dbbf4ad77e85c06970c7', 'title': "in vmware_fusion one can retrieve vm's eth0 ipaddresses", 'body': 'in fusion, it stores the dhcp reservation table for all the guest vms in:\\r \\r /var/db/vmware/\\r \\r in theory it should be possible to have hosts populate /etc/hosts from there  we need to retrieve the eth0 mac address from vmware  to populate that information. this also removes the dependency on a secondary network interface and other crazy things since by default fusion guests can get nated internet & talk to each other.'}
# {'_id': '60f8dbbf4ad77e85c06970e0', 'title': 'convert to function', 'body': 'take elevmap script and convert it to a function.'}
# {'_id': '60f8dbbf4ad77e85c0696f9f', 'title': 'provide a way to remove tiny-date-picker from element', 'body': 'some sort of  unbind  method on the context, to remove the various event listeners from the input element that get added in the main function, would be a very helpful addition to this library.'}
# {'_id': '60f8dbbf4ad77e85c0696faf', 'title': 'uncaught error: user-open error: object does not implement the interface  mainrenderer:39', 'body': 'automatically generated error report \\r version: 0.1.12-beta \\r host os: linux \\r host dist: ubuntu linux undefined\\r package: snap \\r host arch: x64 \\r node: v8.2.1 \\r \\r error log: http://paste.ubuntu.com/p/fxbytbs9y7/ \\r'}
# {'_id': '60f8dbbf4ad77e85c0696fc9', 'title': 'stripe  does not use money protocol', 'body': 'x  use the money protocol\\r       update test cases and examples'}
# {'_id': '60f8dbbf4ad77e85c0696fe3', 'title': 'implicit type conversion in onchange for bootstrap <select> renderer  and mayve others', 'body': 'field meta:\\r \\r    js\\r     {\\r       \\ id\\ : \\ sex\\ ,\\r       \\ renderer\\ : {\\r         \\ type\\ : \\ select\\ ,\\r         \\ config\\ : {\\r           \\ label\\ : \\ sex\\ ,\\r           \\ title\\ : \\ choose your gender\\ ,\\r           \\ options\\ :  \\r             { \\ id\\ : 0, \\ title\\ : \\ female\\  },\\r             { \\ id\\ : 1, \\ title\\ : \\ male\\  },\\r             { \\ id\\ : 2, \\ title\\ : \\ other\\  }\\r            \\r         }\\r       }\\r     },\\r    \\r \\r field data  after  onchange  :\\r    js\\r {\\r   ...\\r   sex: {value: \\ 1\\ , isdirty: true}\\r }\\r'}
# {'_id': '60f8dbbf4ad77e85c069701e', 'title': 'coverage not checked for all packages', 'body': "\\r go list -f '{{if len .testgofiles}}\\ go test -coverprofile={{.dir}}/.coverprofile {{.importpath}}\\ {{end}}' ./... | xargs sh -c\\r    \\r \\r omits directories with no test files  and also  \\ github.com/grtl/mysql-operator/logging\\  ...  giving fake impression of 100% coverage."}
# {'_id': '60f8dbbf4ad77e85c0697041', 'title': 'add ability to override default darray buffer size in cmake/autotool build systems', 'body': 'see  1203.\\r \\r given the hardware variability of hpc systems, we will do well to allow an override of the default darray buffer size. this is easy to build in as an option on the build systems.'}
# {'_id': '60f8dbbf4ad77e85c0697058', 'title': 'feat device-ui : add method to pan the device display', 'body': 'as of 7bae06b, the device ui supports zooming, but does not support panning.\\r \\r panning used to work by right-clicking  see  here  1  , but now right-click brings up the context menu.  maybe we can use something like  <shift><right-click> ?  perhaps it is possible to just disable the context menu behaviour while, e.g.,  <shift>  is held?'}
# {'_id': '60f8dbbf4ad77e85c0697060', 'title': 'i want to allow an ai player to play blackjack, to understand different strategies.', 'body': "instead of waiting for human input for each decision  hit, stand, bet amount , i want to be able to create an ai player who follows simple rules:\\r \\r 1. h17 strategy  used by dealers in many games \\r     - always bet minimum allowed bet\\r     - 16-: hit\\r     - soft 17: hit\\r          - a soft 17 is a hand that could be 17 or seven, like  6 + a  or  4 + 2 + a . \\r          - note:  10 + 6 + a  is not soft, even though it has an ace\\r     - hard 17: stay\\r         - hard 17 is a hand whose minimum value is 17, like  10 + 7  or  9 + 8  or  10 + 6 + a \\r     - 18+ stay\\r 2. s17 strategy  used by dealers in many games \\r     - always bet minimum allowed bet\\r     - 16-: hit\\r     - 17+: stay \\r 3. copy dealer\\r     - always bet minimum allowed bet\\r     - 16-: hit\\r     - 18+: stay\\r     - hard 17: stay\\r     - soft 17: do whatever the dealer of the current game would do\\r 4. opposite of dealer\\r     - always bet minimum allowed bet\\r     - 16-: hit\\r     - 18+: stay\\r     - hard 17: stay\\r     - soft 17: do whatever the dealer of the current game would do\\r \\r i want to be able to choose which strategy the ai uses, the ai's starting money, and the number of rounds they will play. they will play until they lose all their money, or until they've played the selected number of rounds. doing this will help me understand blackjack strategy and odds better."}
# {'_id': '60f8dbbf4ad77e85c0697077', 'title': 'ship support for gsl integrators directly in brian 2?', 'body': "@charleesf is making good progress wrapping up her gsoc project on adding support for numerical integration with the gsl  most importantly adding support for variable time step integration -- of course still within the context of grid-based spike propagation, etc. . the way she wrote it makes it possible to either ship it as a separate module  i.e. something that needs to be installed separately like, say,  brian2genn   or as part of brian itself. i see some merits for both solutions: shipping it separately avoids a dependency on the gsl and simplifies testing, etc.; shipping it with brian itself makes it more discoverable and more likely to be actually used.\\r i tend towards including it in brian itself, to make sure that users are actually aware of it and using it, as well as avoiding problems of it getting out of sync with brian's main code. in the long run, a dependency on gsl might be something useful anyway, e.g. for random number generation.\\r \\r @thesamovar: what do you think?\\r \\r oh, one more point that might speak against its inclusion: currently, only c-based codegen targets are supported  i.e. weave, cython + c++ standalone , numpy does not work."}
# {'_id': '60f8dbbf4ad77e85c069707e', 'title': 'android crashes when monitoring background events', 'body': "tested with the example project.\\r \\r when an enter event is triggered while the app is in the background  still running, not terminated  the app crashes with the following error in the console\\r \\r    \\r e/flutter   2680 :  error:topaz/lib/tonic/logging/dart_error.cc 16   unhandled exception:\\r e/flutter   2680 : 'file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/codec.dart': failed assertion: line 161 pos 16: 'false': cannot parse json to monitoringstate: enter\\r e/flutter   2680 :  0      _assertionerror._dothrownew  dart:core/runtime/liberrors_patch.dart:37:39 \\r e/flutter   2680 :  1      _assertionerror._thrownew  dart:core/runtime/liberrors_patch.dart:33:5 \\r e/flutter   2680 :  2      _jsoncodec.monitoringstatefromjson  file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/codec.dart \\r e/flutter   2680 :  3      _jsoncodec.monitoringresultfromjson  file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/codec.dart:96:32 \\r e/flutter   2680 :  4      _codec.decodemonitoringresult  file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/codec.dart:14:18 \\r e/flutter   2680 :  5      _channels.monitoring.<anonymous closure>  file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/channel.dart:54:21 \\r e/flutter   2680 :  6      _mapstream._handledata  dart:async/stream_pipe.dart:227:21 \\r e/flutter   2680 :  7      _forwardingstreamsubscription._handledata  dart:async/stream_pipe.dart:164:13 \\r e/flutter   2680 :  8      _rootzone.rununaryguarded  dart:async/zone.dart:1316:10 \\r e/flutter   2680 :  9      _bufferingstreamsubscription._senddata  dart:async/stream_impl.dart:330:11 \\r e/flutter   2680 :  10     _delayeddata.perform  dart:async/stream_impl.dart:578:14 \\r e/flutter   2680 :  11     _streamimplevents.handlenext  dart:async/stream_impl.dart:694:11 \\r e/flutter   2680 :  12     _pendingevents.schedule.<anonymous closure>  dart:async/stream_impl.dart:654:7 \\r e/flutter   2680 :  13     _microtaskloop  dart:async/schedule_microtask.dart:41:21 \\r e/flutter   2680 :  14     _startmicrotaskloop  dart:async/schedule_microtask.dart:50:5 \\r e/flutter   2680 :  error:topaz/lib/tonic/logging/dart_error.cc 16   unhandled exception:\\r e/flutter   2680 : 'file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/codec.dart': failed assertion: line 161 pos 16: 'false': cannot parse json to monitoringstate: enter\\r e/flutter   2680 :  0      _assertionerror._dothrownew  dart:core/runtime/liberrors_patch.dart:37:39 \\r e/flutter   2680 :  1      _assertionerror._thrownew  dart:core/runtime/liberrors_patch.dart:33:5 \\r e/flutter   2680 :  2      _jsoncodec.monitoringstatefromjson  file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/codec.dart \\r e/flutter   2680 :  3      _jsoncodec.monitoringresultfromjson  file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/codec.dart:96:32 \\r e/flutter   2680 :  4      _codec.decodemonitoringresult  file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/codec.dart:14:18 \\r e/flutter   2680 :  5      _channels.monitoring.<anonymous closure>  file:///users/alfuller/development/flutter/.pub-cache/hosted/pub.dartlang.org/beacons-0.2.1/lib/channel/channel.dart:54:21 \\r e/flutter   2680 :  6      _mapstream._handledata  dart:async/stream_pipe.dart:227:21 \\r e/flutter   2680 :  7      _forwardingstreamsubscription._handledata  dart:async/stream_pipe.dart:164:13 \\r e/flutter   2680 :  8      _rootzone.rununaryguarded  dart:asy ...
# {'_id': '60f8dbbf4ad77e85c0697096', 'title': 'improve integration time', 'body': 'the current model takes 0.855s for a 9310 points light curve. \\r would like to do better than this, especially after add in the more complicated model.'}
# {'_id': '60f8dbbf4ad77e85c06970a6', 'title': 'enable to get users from sdk', 'body': 'goal  enable to get users from sdk    documentation  mercado pago does not have a good documentation of how to do that, but has the following endpoint     bash https://api.mercadopago.com/users/3?access_token=test-3716-121113-7ac6b5b4f059fcc5c2e6630db047b7b8__lb_la__-74108466      and you can use the following call:     bash curl -x get     -h \\ cache-control: no-cache\\      -h \\ postman-token: b63cd5c2-af18-7f7a-0255-5240aae68baf\\  \\ https://api.mercadopago.com/users/1?access_token=your_access_token\\'}
# {'_id': '60f8dbbf4ad77e85c06970c5', 'title': 'slack github integration requires testing', 'body': 'changes to issues and prs should now be reported in the  gecko-16 slack channel.'}
# {'_id': '60f8dbbf4ad77e85c0696f90', 'title': 'fix responsive tab bar for my activities', 'body': '@ippudo please fix the tab bar on mobile size for  my activities . at this size, the user is unable to click on the  result setting  tab since there are too many tabs. make this  tab bar  scrollable.\\r \\r ! image  https://user-images.githubusercontent.com/4350404/46276195-88233400-c589-11e8-9494-a54257e18b85.png \\r'}
# {'_id': '60f8dbbf4ad77e85c0696f93', 'title': 'clicking on image in tensorboard should open in new window', 'body': 'right now the image may be squashed and hard to read: ! image  https://cloud.githubusercontent.com/assets/51059/18482149/0324d058-79ad-11e6-83a4-d782b523065d.png   the current solution is to copy the image url and manually open in a new tab.'}
# {'_id': '60f8dbbf4ad77e85c0696fab', 'title': 'lms7002m gui theming layout issues', 'body': 'i have noticed this for a while, but i finally tried to look into it because its making the testing near impossible. it looks like wxstaticboxsizer does not take into account the size of its label, and all of the nested box-sizers gradually loose more and more screen space the deeper they nest... just a guess. but every tab, every dialog looks like this more or less.  ! screenshot  http://i.imgur.com/eko8xci.png   @rjonaitis any ideas/hints?'}
# {'_id': '60f8dbbf4ad77e85c0696fb0', 'title': 'multiple data sources for components', 'body': 'the decentralization feature will be complete only once any component is able to fetch its data from several sources concurrently. eg: the events calendar should be able to fetch events, in real time, from many different websites.'}
# {'_id': '60f8dbbf4ad77e85c0696fc5', 'title': 'update and enhance pricing, permissions and versioning', 'body': 'right now this is based off of: http://developers.algorithmia.com/basics/algorithm_basics/ and now at: https://test.algorithmia.com/developers/basics/\\r needs to be updated and added to - especially the \\ pricing\\  section. jon has some ideas about how to make the \\ versioning\\  section better as well.'}
# {'_id': '60f8dbbf4ad77e85c0696fdb', 'title': 'rebuild jsplyr to use prototypes', 'body': 'current model creates new objects with their own identical methods but they are unique to the object. they should all share the same prototype.'}
# {'_id': '60f8dbbf4ad77e85c0696ff2', 'title': 'exception in zest add-on without script console add-on installed', 'body': 'issue reported in owasp zap developer group: https://groups.google.com/d/topic/zaproxy-develop/tijmfnpi8pc/discussion\\r \\r steps to reproduce the issue:\\r 1. run zap, without zest and script console add-ons;\\r 2. install the zest add-on;\\r 3. check the log file, there should be an exception:\\r    \\r 34133  thread-10  info org.zaproxy.zap.extension.autoupdate.extensionautoupdate  - installing new addon zest v21\\r 34246  thread-10  error org.parosproxy.paros.extension.extensionloader  - \\r java.lang.nullpointerexception\\r \\tat org.zaproxy.zap.extension.zest.dialogs.zestdialogmanager.initialize unknown source \\r \\tat org.zaproxy.zap.extension.zest.dialogs.zestdialogmanager.<init> unknown source \\r \\tat org.zaproxy.zap.extension.zest.extensionzest.hook unknown source \\r \\tat org.parosproxy.paros.extension.extensionloader.startlifecycle unknown source \\r \\tat org.zaproxy.zap.control.addoninstaller.installaddonextensionimpl unknown source \\r \\tat org.zaproxy.zap.control.addoninstaller.installaddonextensions unknown source \\r \\tat org.zaproxy.zap.control.addoninstaller.install unknown source \\r \\tat org.zaproxy.zap.control.addonloader.addaddonimpl unknown source \\r \\tat org.zaproxy.zap.control.addonloader.addaddon unknown source \\r \\tat org.zaproxy.zap.extension.autoupdate.extensionautoupdate.install unknown source \\r \\tat org.zaproxy.zap.extension.autoupdate.extensionautoupdate.installnewextensions unknown source \\r \\tat org.zaproxy.zap.extension.autoupdate.extensionautoupdate$3.run unknown source \\r    \\r attempting to uninstall it will also lead to an exception:\\r    \\r 22537  swingworker-pool-1-thread-1  error org.zaproxy.zap.control.addoninstaller  - an error occurred while uninstalling the extension \\ extensionzest\\  bundled in the add-on \\ zest\\ :\\r java.lang.nullpointerexception\\r \\tat org.zaproxy.zap.extension.zest.extensionzest.unload unknown source \\r \\tat org.zaproxy.zap.control.addoninstaller.uninstalladdonextension unknown source \\r \\tat org.zaproxy.zap.control.addoninstaller.uninstalladdonextensions unknown source \\r \\tat org.zaproxy.zap.control.addoninstaller.uninstall unknown source \\r \\tat org.zaproxy.zap.control.addonloader.removeaddonimpl unknown source \\r \\tat org.zaproxy.zap.control.addonloader.removeaddon unknown source \\r \\tat org.zaproxy.zap.extension.autoupdate.extensionautoupdate.uninstall unknown source \\r \\tat org.zaproxy.zap.extension.autoupdate.extensionautoupdate.access$1100 unknown source \\r \\tat org.zaproxy.zap.extension.autoupdate.extensionautoupdate$10.doinbackground unknown source \\r \\tat org.zaproxy.zap.extension.autoupdate.extensionautoupdate$10.doinbackground unknown source \\r \\tat javax.swing.swingworker$1.call swingworker.java:295 \\r \\tat java.util.concurrent.futuretask.run futuretask.java:266 \\r \\tat javax.swing.swingworker.run swingworker.java:334 \\r \\tat java.util.concurrent.threadpoolexecutor.runworker threadpoolexecutor.java:1142 \\r \\tat java.util.concurrent.threadpoolexecutor$worker.run threadpoolexecutor.java:617 \\r \\tat java.lang.thread.run thread.java:745 \\r    \\r \\r remarks:\\r the first exception also happens when starting zap with zest add-on installed but not script console add-on  or installed but with its extension disabled .\\r \\r zap version:\\r version 2.5.0\\r \\r add-on:\\r \\ zest - graphical security scripting language\\  version 21'}
# {'_id': '60f8dbbf4ad77e85c0697019', 'title': 'extend landsat8 for extreme nns', 'body': 'for meris it is already possible to choose between standard and extreme nets. now we have already extreme nets for landsat 8.'}
# {'_id': '60f8dbbf4ad77e85c0697021', 'title': 'html escape sequences in icon popups', 'body': 'http://lobid.org/nwbib/search?q= &t=http%3a%2f%2fpurl.org%2fontology%2fbibo%2fmultivolumebook\\r \\r hover over type icon ->  mehrb&auml;ndig'}
# {'_id': '60f8dbbf4ad77e85c069702d', 'title': 'add build version for command line', 'body': 'koli version  must return the following information:\\r \\r - the k8s library version  kubernetesversion \\r - the commit linked to the current build  gitcommit \\r - the version of the command line  gitversion \\r - the build date  builddate \\r - the go version  goversion \\r - the compiler  compiler \\r - the os platform  platform \\r'}
# {'_id': '60f8dbbf4ad77e85c069702f', 'title': 'nbest in server outputs', 'body': 'the nbest are put on stdout regardless the verbosity value.'}
# ...
# {'_id': '60f8dbbf4ad77e85c069704c', 'title': 'switch currency attributes from dollars to generic amount', 'body': "donation:\\r -  x   minimum_bid_dollars \\r -  x   estimated_value_dollars \\r \\r bid\\r - we'll remove this model so we don't have to deal with it"}
# {'_id': '60f8dbbf4ad77e85c0697065', 'title': "error: couldn't connect to server after 60 seconds", 'body': "hello, everybody!\\r i hope, you can help me with my problem. i'm trying to build tensorflow v r0.12 with gpu support on windows 8.1.\\r every action i do  including even \\ bazel clean\\ , \\ bazel fetch\\  and \\ bazel info release\\   leads to ~600 dots and error:\\r \\ error: couldn't connect to server after 60 seconds\\ \\r anybody have any ideas?"}
# {'_id': '60f8dbbf4ad77e85c069706c', 'title': 'random line of code appears on every page of this velux theme', 'body': "my site is liahonahomebuilders.com. if you look closely within the header image on each page you'll see a line or two of code in dark gray front that looks like this across the bottom of the pic:\\r  \\r warning: call_user_func_array   expects parameter 1 to be a valid callback, function 'primer_video_header' not found or invalid function name in /home/content/a2pewpnas01_data02/42/4014542/html/wp-includes/class-wp-hook.php on line 298\\r  \\r some variation of this is in the same place on every page.\\r  \\r i thought it was a plugin problem, but when i deactivated all the plugins it was still there. i use this theme on another wp site as well  betterexit.com  and do not have this issue.\\r  \\r so what could it be? please help!"}
# {'_id': '60f8dbbf4ad77e85c069707b', 'title': 'package missing godoc', 'body': 'the package godoc documentation is missing.'}
# {'_id': '60f8dbbf4ad77e85c0697086', 'title': 'domain migration fails to create routes for some apps', 'body': "after restoring from a backup and running a domain migration, the status app and the user app from the backup  there was only one in the backup  didn't have routes for the new domain, only the old one. the other system apps correctly had a route for both domains."}
# {'_id': '60f8dbbf4ad77e85c069708a', 'title': 'ajouter home page html', 'body': 'ajout une page hmtl avec un doctype et tout le tralala'}
# {'_id': '60f8dbbf4ad77e85c069709b', 'title': 'add sync status when updating channels', 'body': "currently, when a user wants to update a channel, he/she doesn't see the progress of the sync which might be problematic since a sync can take a bit of time.\\r \\r the change would mostly happen in  epgsyncloadingguidedfragment \\r \\r potential solutions:\\r \\r - show the number of channels synced\\r - show the syncing percentage"}
# {'_id': '60f8dbbf4ad77e85c06970a5', 'title': 'way to disable per-container memory limit in task definition', 'body': 'according to the docs 1 , the per-container memory limit is required. this is inconvenient, because i use the same elasticbeanstalk  dockerrun.aws.json  file with multiple instance types.\\r \\r is there a way to disable this setting?\\r \\r  1 : http://docs.aws.amazon.com/amazonecs/latest/developerguide/task_definition_parameters.html\\r'}
# {'_id': '60f8dbbf4ad77e85c06970b3', 'title': 'joomla: abilty to load print.css or disable default print style', 'body': 'an option to load a print.css like the custom.css would be great.\\r    html\\r <link rel=\\ stylesheet\\  type=\\ text/css\\  media=\\ print\\  href=\\ templates/hydrogen/custom/print.css\\ >\\r    \\r the hydrogen.css and the custom.css should then be loaded like this:\\r    html\\r <link rel=\\ stylesheet\\  type=\\ text/css\\  media=\\ screen\\  href=\\ templates/hydrogen/custom/hydrogen.css\\ >\\r <link rel=\\ stylesheet\\  type=\\ text/css\\  media=\\ screen\\  href=\\ templates/hydrogen/custom/custom.css\\ >\\r    \\r alternatively a switch to disable the default print styling would help to style in some situations where you have inline styles.\\r'}
# {'_id': '60f8dbbf4ad77e85c06970b5', 'title': 'duplicate key error', 'body': "it seems as though there is an issue with duplicate keys in the  ram  field. when sending a post request to  api/v1/resources/resources , the following is returned:\\r \\r    \\r {  bulkwriteerror: e11000 duplicate key error index: shareresources.resources.$ram_1 dup key: { : 4 } \\r   name: 'bulkwriteerror',\\r   message: 'e11000 duplicate key error index: shareresources.resources.$ram_1 dup key: { : 4 }',\\r   driver: true,\\r   code: 11000,\\r   index: 0,\\r   errmsg: 'e11000 duplicate key error index: shareresources.resources.$ram_1 dup key: { : 4 }',\\r   ...\\r }\\r    \\r \\r i have one resource in  db.resources  outline below:\\r    \\r {\\r \\t\\ _id\\  : objectid \\ 5acc593db7b39a1029eaac0f\\  ,\\r \\t\\ ip_address\\  : \\ 127.0.0.1\\ ,\\r \\t\\ ram\\  : 4,\\r \\t\\ cores\\  : 8,\\r \\t\\ cpus\\  : 2,\\r \\t\\ gpus\\  : 0,\\r \\t\\ status\\  : \\ online\\ ,\\r \\t\\ price\\  : 4,\\r \\t\\ owner\\  : objectid \\ 5ac72c8c0fcb4d7d757bcbdb\\  ,\\r \\t\\ createdby\\  : objectid \\ 5ac72c8c0fcb4d7d757bcbdb\\  ,\\r \\t\\ updatedby\\  : objectid \\ 5ac72c8c0fcb4d7d757bcbdb\\  ,\\r \\t\\ active_from\\  : isodate \\ 2018-04-10t06:27:09.231z\\  ,\\r \\t\\ active_to\\  : isodate \\ 2018-04-10t06:27:09.231z\\  ,\\r \\t\\ createdon\\  : isodate \\ 2018-04-10t06:27:09.231z\\  ,\\r \\t\\ updatedon\\  : isodate \\ 2018-04-10t06:27:09.231z\\  ,\\r \\t\\ __v\\  : 0\\r }\\r    \\r of course, the  ram  field in the resources schema does  not  have  unique: true  set."}
# {'_id': '60f8dbbf4ad77e85c06970bc', 'title': 'textarea content is not updated in ie11', 'body': "http://plnkr.co/edit/ctozbsp65um8qll0owvr?p=preview\\r \\r click button hello - textarea content doesn't change.\\r \\r workaround is to use value attribute for textarea, which is non-standard html, but works due to riot's special handling of input elements in sdom.js\\r"}
# {'_id': '60f8dbbf4ad77e85c06970c0', 'title': 'status page is now showing correctly', 'body': 'this is due to a php tag not used correctly, as the console has been developed using short_open_tag=on, which enables the use of  <?   instead of just  <?php .'}
# {'_id': '60f8dbbf4ad77e85c06970c2', 'title': 'staticmethod tests fail when declared in a superclass', 'body': "staticmethod  test fails if you declare it in a superclass:\\r \\r    \\r @pytest.fixture\\r def fixture  :\\r     return true\\r \\r class testfoo:\\r     @staticmethod\\r     def test_me fixture :\\r         assert fixture\\r \\r class testbar testfoo :\\r     ...\\r    \\r \\r  testbar.test_me  fails due to the  typeerror: test_me   missing 1 required positional argument: 'fixture' .\\r \\r  testfoo.test_me  passes correctly."}
# {'_id': '60f8dbbf4ad77e85c06970d9', 'title': '!bash and discreet sizes - items?', 'body': "since now it is all about +/- size, things like cloak of faeriekind and band of deformities are pretty much broken. why not to change them to be +/- size, unlike what they are now? its pretty easy to fix. and reduced drow wearing cloak of faeriekind will finally be !bash, which will finally address the issue that \\ every caster must be smurf or hobbit nowadays\\ \\r \\r katumi tells you 'a cloak of faeriekind  about  ac:15 hp:40 ht:-25   procs: faer\\r iekind   magic no_charm no_sleep !barb !fighter !ogre !thief !troll   wt:1 val:7\\r 72p   zone: faerie realms  q    last id: 2012-11-26'\\r \\r katumi tells you 'a band of deformities  finger  ac:0 wt:40   wt:0 val:3p   zone\\r : ashstone   last id: 2007-08-29'"}
# {'_id': '60f8dbbf4ad77e85c06970db', 'title': 'using local data with tree grid generates proptypes warning', 'body': "when using the demo grid code the following proptypes error is generated when trying to use the tree with local data.\\r  warning: failed prop type: invalid prop  data  of type  object  supplied to  grid , expected an array. \\r \\r here's the   provider.jsx   setup i used to run the demo code:\\r    \\r import react from 'react';\\r import { provider } from 'react-redux';\\r import { grid, store, applygridconfig } from '../src';\\r \\r import {\\r     columns,\\r     data,\\r     pagesize,\\r     plugins,\\r     events,\\r     datasource,\\r     treedatasource,\\r     stateful,\\r     height,\\r     statekey,\\r     treedata,\\r     examplepromisedatasource\\r } from '../demo/demodata';\\r \\r const config = {\\r     columns,\\r     //data,\\r      data: treedata,\\r     // datasource: treedatasource,\\r     // infinite: true,\\r     stateful: false,\\r     //datasource: examplepromisedatasource,\\r     // draganddrop: true,\\r      gridtype: 'tree',\\r     pagesize,\\r     plugins,\\r     events,\\r     statekey\\r };\\r \\r export default  \\r     <provider store={ store }>\\r         <grid { ...config } />\\r     </provider>\\r  ;\\r    \\r i suspect this is caused by the following in the   grid.jsx   component:\\r          data: arrayof object , \\r"}
# {'_id': '60f8dbbf4ad77e85c0696f5c', 'title': 'integrate boost asio', 'body': 'the continuous integration build should pass and environment variables should be set such that the project can link to the asio library.'}
# {'_id': '60f8dbbf4ad77e85c0696f72', 'title': 'list box styling', 'body': 'list boxes are not styled correct in a3. add necessary layout.'}
# {'_id': '60f8dbbf4ad77e85c0696f80', 'title': 'looks ugly with atom-material-ui', 'body': 'not sure if this is a bug on https://github.com/abe33/atom-tablr or on https://github.com/atom-material/atom-material-ui, but when using atom material theme + one dark for colours, see how it looks editing a cell:\\r \\r ! captura de pantalla de 2016-11-11 09-44-21  https://cloud.githubusercontent.com/assets/973709/20209259/b37b1114-a7f3-11e6-9e30-2415fbf27ee0.png \\r'}
# {'_id': '60f8dbbf4ad77e85c0696f8b', 'title': 'keep record of which namespaces have been indexed and which failed download', 'body': 'when fetching ontologies, keep track of what was fetched successfully and what failed. display this information on the about page next to the list of namespaces.'}
# {'_id': '60f8dbbf4ad77e85c0696f9c', 'title': 'new splash screen', 'body': 'update splash screen with app logo.'}
# {'_id': '60f8dbbf4ad77e85c0696fa6', 'title': "fullscreen video doesn't hide status and navigation bars", 'body': 'if i click fullscreen on a youtube video, it will fill the browser window, but the android status and navigation bars are still visible.'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-83327daf30f6> in <module>
#      50         for col in cols:
#      51             print('Querying documents from collection {} in database {}'.format(col, db))
# ---> 52             for x in CLIENT[db][col].find():
#      53                 try:
#      54
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\cursor.py in next(self)
#    1236         if self.__empty:
#    1237             raise StopIteration
# -> 1238         if len(self.__data) or self._refresh():
#    1239             if self.__manipulate:
#    1240                 _db = self.__collection.database
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1173                                     self.__sock_mgr,
#    1174                                     self.__exhaust)
# -> 1175             self.__send_message(g)
#    1176
#    1177         return len(self.__data)
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#    1042
#    1043         try:
# -> 1044             response = client._run_operation(
#    1045                 operation, self._unpack_response, address=self.__address)
#    1046         except OperationFailure as exc:
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1422                 unpack_res)
#    1423
# -> 1424         return self._retryable_read(
#    1425             _cmd, operation.read_preference, operation.session,
#    1426             address=address, retryable=isinstance(operation, message._Query))
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1523                         # not support retryable reads, raise the last error.
#    1524                         raise last_error
# -> 1525                     return func(session, server, sock_info, secondary_ok)
#    1526             except ServerSelectionTimeoutError:
#    1527                 if retrying:
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\mongo_client.py in _cmd(session, server, sock_info, secondary_ok)
#    1418
#    1419         def _cmd(session, server, sock_info, secondary_ok):
# -> 1420             return server.run_operation(
#    1421                 sock_info, operation, secondary_ok, self._event_listeners,
#    1422                 unpack_res)
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\server.py in run_operation(self, sock_info, operation, set_secondary_okay, listeners, unpack_res)
#     112             else:
#     113                 sock_info.send_message(data, max_doc_size)
# --> 114                 reply = sock_info.receive_message(request_id)
#     115
#     116             # Unpack and check for command errors.
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\pool.py in receive_message(self, request_id)
#     751             return receive_message(self, request_id, self.max_message_size)
#     752         except BaseException as error:
# --> 753             self._raise_connection_failure(error)
#     754
#     755     def _raise_if_not_writable(self, unacknowledged):
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\pool.py in receive_message(self, request_id)
#     749         """
#     750         try:
# --> 751             return receive_message(self, request_id, self.max_message_size)
#     752         except BaseException as error:
#     753             self._raise_connection_failure(error)
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\network.py in receive_message(sock_info, request_id, max_message_size)
#     213             compressor_id)
#     214     else:
# --> 215         data = _receive_data_on_socket(sock_info, length - 16, deadline)
#     216
#     217     try:
#
# c:\users\argos\appdata\local\programs\python\python39\lib\site-packages\pymongo\network.py in _receive_data_on_socket(sock_info, length, deadline)
#     285             try:
#     286                 wait_for_read(sock_info, deadline)
# --> 287                 chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     288             except (IOError, OSError) as exc:
#     289                 if _errno_from_exception(exc) == errno.EINTR:
#
# c:\users\argos\appdata\local\programs\python\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\argos\appdata\local\programs\python\python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
